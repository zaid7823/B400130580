# %%
# 1. Import the necessary libraries

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, input

# 2. Load the dataset
df = pd.read_csv('')
df.head()

# %%
# 3. Partitioning the data into features and target
X = df.drop('MEDV', axis=1)
y = df['MEDV']

# 4. Splitting the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.3, random_state=42)

# %%
# 5. Normalization of features using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# 6. Checking the no. of features for the model
print(f"Number of features: {len(X.columns)}")

# %%
# Defining the Neural Network

model = Sequential([
    Input(shape=(13, )),
    Dense(128, activation='relu', name='dense_1'),
    Dense(64, activation='relu', name='dense_2'),
    Dense(1, activation='linear', name='dense_output'),
])

# Compiling the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Model Summary - includes layers, params, and shape
model.summary()

# %%
# Training the model
history = model.fit(x_train, y_train, validation_split=0.05, verbose=1)

# Evaluation of model on test data
mse, mae = model.evaluate(x_test, y_test)
print(f"Mean Squared Error on test data: {mse}")
print(f"Mean Absolute Error on test data: {mae}")
